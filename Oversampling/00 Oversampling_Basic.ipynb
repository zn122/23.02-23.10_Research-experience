# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_recall_curve,confusion_matrix, auc,roc_curve
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold
from sklearn.preprocessing import StandardScaler
from datetime import datetime, date, time
from functools import reduce
import catboost
import pandas as pd
import numpy as np
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('mode.chained_assignment',  None)
pd.set_option('display.max_columns',500)

# %%
merge_df = pd.read_csv('merge_df.csv')
merge_df = merge_df.fillna(merge_df.mean())

# %%
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)
  
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
# 0 번째
# Youden index threshold :  0.15515048109536442
# roc_auc_score :  0.7375
# acc :  0.7241379310344828
# sensitivity :  0.7
# specificity :  0.7291666666666666
# pr_auc :  0.5022289007482466
#
# [[35 13]
#  [ 3  7]]
# 1 번째
# Youden index threshold :  0.35891395645632435
# roc_auc_score :  0.70625
# acc :  0.6379310344827587
# sensitivity :  0.9
# specificity :  0.5833333333333334
# pr_auc :  0.27451150260023394
#
# [[28 20]
#  [ 1  9]]
# 2 번째
# Youden index threshold :  0.446136226117855
# roc_auc_score :  0.75
# acc :  0.8103448275862069
# sensitivity :  0.7
# specificity :  0.8333333333333334
# pr_auc :  0.46173495754891103
#
# [[40  8]
#  [ 3  7]]
# 3 번째
# Youden index threshold :  0.058079911145375106
# roc_auc_score :  0.7120181405895691
# acc :  0.7931034482758621
# sensitivity :  0.6666666666666666
# specificity :  0.8163265306122449
# pr_auc :  0.452692363548418
#
# [[40  9]
#  [ 3  6]]
# 4 번째
# Youden index threshold :  0.18903306555914764
# roc_auc_score :  0.6157407407407408
# acc :  0.631578947368421
# sensitivity :  0.6666666666666666
# specificity :  0.625
# pr_auc :  0.2614514575516188
#
# [[30 18]
#  [ 3  6]]
# 5 번째
# Youden index threshold :  0.34112884947126176
# roc_auc_score :  0.7729166666666667
# acc :  0.7758620689655172
# sensitivity :  0.7
# specificity :  0.7916666666666666
# pr_auc :  0.4946863246726948
#
# [[38 10]
#  [ 3  7]]
# 6 번째
# Youden index threshold :  0.20024196732074231
# roc_auc_score :  0.55625
# acc :  0.7241379310344828
# sensitivity :  0.4
# specificity :  0.7916666666666666
# pr_auc :  0.2926076933843238
#
# [[38 10]
#  [ 6  4]]
# 7 번째
# Youden index threshold :  0.07020590936808627
# roc_auc_score :  0.5979166666666667
# acc :  0.3793103448275862
# sensitivity :  1.0
# specificity :  0.25
# pr_auc :  0.37791784238613
#
# [[12 36]
#  [ 0 10]]
# 8 번째
# Youden index threshold :  0.4923714325338307
# roc_auc_score :  0.5204081632653061
# acc :  0.7413793103448276
# sensitivity :  0.3333333333333333
# specificity :  0.8163265306122449
# pr_auc :  0.16031049165107136
#
# [[40  9]
#  [ 6  3]]
# 9 번째
# Youden index threshold :  0.3049846319768359
# roc_auc_score :  0.7361111111111112
# acc :  0.7017543859649122
# sensitivity :  0.7777777777777778
# specificity :  0.6875
# pr_auc :  0.3315216709579455
#
# [[33 15]
#  [ 2  7]]
# 10 번째
# Youden index threshold :  0.07248193169769376
# roc_auc_score :  0.58125
# acc :  0.5172413793103449
# sensitivity :  0.8
# specificity :  0.4583333333333333
# pr_auc :  0.2880250418534125
#
# [[22 26]
#  [ 2  8]]
# 11 번째
# Youden index threshold :  0.08105149727299657
# roc_auc_score :  0.675
# acc :  0.5862068965517241
# sensitivity :  0.8
# specificity :  0.5416666666666666
# pr_auc :  0.3520503731540242
#
# [[26 22]
#  [ 2  8]]
# 12 번째
# Youden index threshold :  0.12547858354357874
# roc_auc_score :  0.7145833333333335
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.44607124904264983
#
# [[36 12]
#  [ 3  7]]
# 13 번째
# Youden index threshold :  0.4874941739954046
# roc_auc_score :  0.5056689342403629
# acc :  0.7758620689655172
# sensitivity :  0.3333333333333333
# specificity :  0.8571428571428571
# pr_auc :  0.18492237558063887
#
# [[42  7]
#  [ 6  3]]
# 14 번째
# Youden index threshold :  0.08046643189707602
# roc_auc_score :  0.7199074074074074
# acc :  0.6666666666666666
# sensitivity :  0.7777777777777778
# specificity :  0.6458333333333334
# pr_auc :  0.3275786676932702
#
# [[31 17]
#  [ 2  7]]
# 15 번째
# Youden index threshold :  0.08875559850080118
# roc_auc_score :  0.6145833333333334
# acc :  0.6724137931034483
# sensitivity :  0.8
# specificity :  0.6458333333333334
# pr_auc :  0.20915314645593586
#
# [[31 17]
#  [ 2  8]]
# 16 번째
# Youden index threshold :  0.29327069927912675
# roc_auc_score :  0.6104166666666666
# acc :  0.8103448275862069
# sensitivity :  0.4
# specificity :  0.8958333333333334
# pr_auc :  0.35333589897128515
#
# [[43  5]
#  [ 6  4]]
# 17 번째
# Youden index threshold :  0.09444894870047515
# roc_auc_score :  0.6979166666666666
# acc :  0.7586206896551724
# sensitivity :  0.7
# specificity :  0.7708333333333334
# pr_auc :  0.4527287947423796
#
# [[37 11]
#  [ 3  7]]
# 18 번째
# Youden index threshold :  0.39483812907882254
# roc_auc_score :  0.6780045351473922
# acc :  0.7241379310344828
# sensitivity :  0.6666666666666666
# specificity :  0.7346938775510204
# pr_auc :  0.4057039289172932
#
# [[36 13]
#  [ 3  6]]
# 19 번째
# Youden index threshold :  0.4685951028899102
# roc_auc_score :  0.6111111111111112
# acc :  0.631578947368421
# sensitivity :  0.7777777777777778
# specificity :  0.6041666666666666
# pr_auc :  0.18898467090207555
#
# [[29 19]
#  [ 2  7]]

# %%
print('basic : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# basic :
# proba_score 0.6556776738473167
# re_score 0.68
# specifi_score 0.6914328231292518
# [0.7375,
#  0.70625,
#  0.75,
#  0.7120181405895691,
#  0.6157407407407408,
#  0.7729166666666667,
#  0.55625,
#  0.5979166666666667,
#  0.5204081632653061,
#  0.7361111111111112,
#  0.58125,
#  0.675,
#  0.7145833333333335,
#  0.5056689342403629,
#  0.7199074074074074,
#  0.6145833333333334,
#  0.6104166666666666,
#  0.6979166666666666,
#  0.6780045351473922,
#  0.6111111111111112]

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    #SMOTE로 타겟의 분포를 균등하게 조절
    smote = SMOTE(random_state=42)
    x_train_sk, y_train_sk = smote.fit_resample(x_train_sk, y_train_sk)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train_sk).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.0344497638597603
# roc_auc_score :  0.6520833333333332
# acc :  0.5517241379310345
# sensitivity :  0.9
# specificity :  0.4791666666666667
# pr_auc :  0.2532928534844663
#
# [[23 25]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.41662571828853057
# roc_auc_score :  0.8500000000000001
# acc :  0.7241379310344828
# sensitivity :  1.0
# specificity :  0.6666666666666666
# pr_auc :  0.5765419480050318
#
# [[32 16]
#  [ 0 10]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.463690008753108
# roc_auc_score :  0.5770833333333334
# acc :  0.46551724137931033
# sensitivity :  0.8
# specificity :  0.3958333333333333
# pr_auc :  0.19354203607689974
#
# [[19 29]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.5126542105292249
# roc_auc_score :  0.528344671201814
# acc :  0.8793103448275862
# sensitivity :  0.3333333333333333
# specificity :  0.9795918367346939
# pr_auc :  0.35672745447054055
#
# [[48  1]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.4985286349769391
# roc_auc_score :  0.5717592592592592
# acc :  0.7894736842105263
# sensitivity :  0.3333333333333333
# specificity :  0.875
# pr_auc :  0.199858632819487
#
# [[42  6]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.41125054467512856
# roc_auc_score :  0.7041666666666666
# acc :  0.6896551724137931
# sensitivity :  0.7
# specificity :  0.6875
# pr_auc :  0.30415913813679446
#
# [[33 15]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.24746346465865618
# roc_auc_score :  0.66875
# acc :  0.8103448275862069
# sensitivity :  0.6
# specificity :  0.8541666666666666
# pr_auc :  0.3433886930138249
#
# [[41  7]
#  [ 4  6]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.137621634687377
# roc_auc_score :  0.6666666666666666
# acc :  0.6724137931034483
# sensitivity :  0.8
# specificity :  0.6458333333333334
# pr_auc :  0.2323304705809096
#
# [[31 17]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.13122828125070582
# roc_auc_score :  0.7165532879818595
# acc :  0.7068965517241379
# sensitivity :  0.7777777777777778
# specificity :  0.6938775510204082
# pr_auc :  0.45406171151785185
#
# [[34 15]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.4240234764646313
# roc_auc_score :  0.6365740740740741
# acc :  0.6140350877192983
# sensitivity :  0.7777777777777778
# specificity :  0.5833333333333334
# pr_auc :  0.20530868389919177
#
# [[28 20]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.16162552537449107
# roc_auc_score :  0.7333333333333333
# acc :  0.7241379310344828
# sensitivity :  0.7
# specificity :  0.7291666666666666
# pr_auc :  0.28814210532243256
#
# [[35 13]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.10748278783305062
# roc_auc_score :  0.5916666666666667
# acc :  0.5517241379310345
# sensitivity :  0.9
# specificity :  0.4791666666666667
# pr_auc :  0.18623524994549773
#
# [[23 25]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.4753242113281233
# roc_auc_score :  0.6604166666666667
# acc :  0.6206896551724138
# sensitivity :  0.8
# specificity :  0.5833333333333334
# pr_auc :  0.355947377915213
#
# [[28 20]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.5020558721992106
# roc_auc_score :  0.5419501133786848
# acc :  0.7758620689655172
# sensitivity :  0.3333333333333333
# specificity :  0.8571428571428571
# pr_auc :  0.2720207343808662
#
# [[42  7]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.2655102561020557
# roc_auc_score :  0.7615740740740741
# acc :  0.6842105263157895
# sensitivity :  0.7777777777777778
# specificity :  0.6666666666666666
# pr_auc :  0.4715302621192265
#
# [[32 16]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.36126961574758537
# roc_auc_score :  0.6354166666666666
# acc :  0.8103448275862069
# sensitivity :  0.5
# specificity :  0.875
# pr_auc :  0.4081319522809911
#
# [[42  6]
#  [ 5  5]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.49837016984381627
# roc_auc_score :  0.6010416666666667
# acc :  0.7241379310344828
# sensitivity :  0.6
# specificity :  0.75
# pr_auc :  0.21198985364210066
#
# [[36 12]
#  [ 4  6]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.2504468836998509
# roc_auc_score :  0.6479166666666667
# acc :  0.7586206896551724
# sensitivity :  0.6
# specificity :  0.7916666666666666
# pr_auc :  0.24226384362768427
#
# [[38 10]
#  [ 4  6]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.20052312880401071
# roc_auc_score :  0.7142857142857143
# acc :  0.7758620689655172
# sensitivity :  0.6666666666666666
# specificity :  0.7959183673469388
# pr_auc :  0.24922616271033043
#
# [[39 10]
#  [ 3  6]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.48526319838358417
# roc_auc_score :  0.8842592592592593
# acc :  0.8421052631578947
# sensitivity :  0.8888888888888888
# specificity :  0.8333333333333334
# pr_auc :  0.45065422366147
#
# [[40  8]
#  [ 1  8]]

# %%
print('SMOTE 5 4 : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# SMOTE 5 4 :
# proba_score 0.6671921060090703
# re_score 0.6894444444444445
# specifi_score 0.7111181972789116
# [0.6520833333333332,
#  0.8500000000000001,
#  0.5770833333333334,
#  0.528344671201814,
#  0.5717592592592592,
#  0.7041666666666666,
#  0.66875,
#  0.6666666666666666,
#  0.7165532879818595,
#  0.6365740740740741,
#  0.7333333333333333,
#  0.5916666666666667,
#  0.6604166666666667,
#  0.5419501133786848,
#  0.7615740740740741,
#  0.6354166666666666,
#  0.6010416666666667,
#  0.6479166666666667,
#  0.7142857142857143,
#  0.8842592592592593]

# %% [markdown]
# # BorderlineSMOTE

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    bsmote = BorderlineSMOTE(random_state=42)
    x_train_sk, y_train_sk = bsmote.fit_resample(x_train_sk, y_train_sk)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train_sk).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.4850520247407377
# roc_auc_score :  0.603125
# acc :  0.5172413793103449
# sensitivity :  0.8
# specificity :  0.4583333333333333
# pr_auc :  0.21898405929637133
#
# [[22 26]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.18540590859145598
# roc_auc_score :  0.7791666666666667
# acc :  0.6551724137931034
# sensitivity :  1.0
# specificity :  0.5833333333333334
# pr_auc :  0.3936551205566632
#
# [[28 20]
#  [ 0 10]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.08014971433882917
# roc_auc_score :  0.7000000000000001
# acc :  0.7586206896551724
# sensitivity :  0.7
# specificity :  0.7708333333333334
# pr_auc :  0.39678994473275153
#
# [[37 11]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.47016728563411925
# roc_auc_score :  0.5374149659863946
# acc :  0.7586206896551724
# sensitivity :  0.3333333333333333
# specificity :  0.8367346938775511
# pr_auc :  0.18097201389371864
#
# [[41  8]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.48733719949767895
# roc_auc_score :  0.6342592592592593
# acc :  0.8245614035087719
# sensitivity :  0.3333333333333333
# specificity :  0.9166666666666666
# pr_auc :  0.34703949147409774
#
# [[44  4]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.43962201720334054
# roc_auc_score :  0.5708333333333333
# acc :  0.7931034482758621
# sensitivity :  0.3
# specificity :  0.8958333333333334
# pr_auc :  0.2303565194181082
#
# [[43  5]
#  [ 7  3]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.06269694076927347
# roc_auc_score :  0.7041666666666666
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.3103261871656235
#
# [[36 12]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.09712802450247703
# roc_auc_score :  0.65625
# acc :  0.6551724137931034
# sensitivity :  0.9
# specificity :  0.6041666666666666
# pr_auc :  0.220223740592915
#
# [[29 19]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.4993118175149563
# roc_auc_score :  0.5873015873015872
# acc :  0.7586206896551724
# sensitivity :  0.4444444444444444
# specificity :  0.8163265306122449
# pr_auc :  0.2557059500458953
#
# [[40  9]
#  [ 5  4]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.4086890651054094
# roc_auc_score :  0.8078703703703703
# acc :  0.7719298245614035
# sensitivity :  0.7777777777777778
# specificity :  0.7708333333333334
# pr_auc :  0.34757681860623035
#
# [[37 11]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.08996874207948413
# roc_auc_score :  0.7104166666666667
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.2545672486472587
#
# [[36 12]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.01958876138989251
# roc_auc_score :  0.5625
# acc :  0.46551724137931033
# sensitivity :  0.9
# specificity :  0.375
# pr_auc :  0.17885611505941018
#
# [[18 30]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.4203050318059523
# roc_auc_score :  0.6437500000000002
# acc :  0.6206896551724138
# sensitivity :  0.8
# specificity :  0.5833333333333334
# pr_auc :  0.3927074275808339
#
# [[28 20]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.46968341903600574
# roc_auc_score :  0.5986394557823129
# acc :  0.603448275862069
# sensitivity :  0.6666666666666666
# specificity :  0.5918367346938775
# pr_auc :  0.307340764008394
#
# [[29 20]
#  [ 3  6]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.4094012854326039
# roc_auc_score :  0.7268518518518519
# acc :  0.8947368421052632
# sensitivity :  0.4444444444444444
# specificity :  0.9791666666666666
# pr_auc :  0.5497843153668851
#
# [[47  1]
#  [ 5  4]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.2731716976663608
# roc_auc_score :  0.6666666666666666
# acc :  0.7586206896551724
# sensitivity :  0.5
# specificity :  0.8125
# pr_auc :  0.2599067496868287
#
# [[39  9]
#  [ 5  5]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.3611491385052943
# roc_auc_score :  0.6583333333333333
# acc :  0.6379310344827587
# sensitivity :  0.8
# specificity :  0.6041666666666666
# pr_auc :  0.3404374827459323
#
# [[29 19]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.21791088434976572
# roc_auc_score :  0.575
# acc :  0.5517241379310345
# sensitivity :  0.8
# specificity :  0.5
# pr_auc :  0.18873236720221723
#
# [[24 24]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    153
# 1    153
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.06483394151731485
# roc_auc_score :  0.7324263038548753
# acc :  0.7068965517241379
# sensitivity :  0.7777777777777778
# specificity :  0.6938775510204082
# pr_auc :  0.28885644720743653
#
# [[34 15]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    154
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.45435969380739044
# roc_auc_score :  0.8449074074074073
# acc :  0.7894736842105263
# sensitivity :  0.8888888888888888
# specificity :  0.7708333333333334
# pr_auc :  0.7260398912604309
#
# [[37 11]
#  [ 1  8]]

# %%
print('BorderlineSMOTE-1 5 4 : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# BorderlineSMOTE-1 5 4 :
# proba_score 0.6649939767573695
# re_score 0.6783333333333335
# specifi_score 0.7031887755102042
# [0.603125,
#  0.7791666666666667,
#  0.7000000000000001,
#  0.5374149659863946,
#  0.6342592592592593,
#  0.5708333333333333,
#  0.7041666666666666,
#  0.65625,
#  0.5873015873015872,
#  0.8078703703703703,
#  0.7104166666666667,
#  0.5625,
#  0.6437500000000002,
#  0.5986394557823129,
#  0.7268518518518519,
#  0.6666666666666666,
#  0.6583333333333333,
#  0.575,
#  0.7324263038548753,
#  0.8449074074074073]

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    adasyn = ADASYN(random_state = 42)
    x_train_sk, y_train_sk = adasyn.fit_resample(x_train_sk, y_train_sk)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train_sk).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  0    154
# 1    148
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.12478781419090107
# roc_auc_score :  0.6625
# acc :  0.5344827586206896
# sensitivity :  0.9
# specificity :  0.4583333333333333
# pr_auc :  0.31694120157639605
#
# [[22 26]
#  [ 1  9]]
#  변화된 값의 분포 :
#  1    157
# 0    154
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.18186855310118483
# roc_auc_score :  0.8604166666666666
# acc :  0.7586206896551724
# sensitivity :  0.9
# specificity :  0.7291666666666666
# pr_auc :  0.42936156572185985
#
# [[35 13]
#  [ 1  9]]
#  변화된 값의 분포 :
#  1    162
# 0    154
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.23479581402723596
# roc_auc_score :  0.6583333333333333
# acc :  0.41379310344827586
# sensitivity :  1.0
# specificity :  0.2916666666666667
# pr_auc :  0.34743587279287547
#
# [[14 34]
#  [ 0 10]]
#  변화된 값의 분포 :
#  1    166
# 0    153
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.3233529594824198
# roc_auc_score :  0.6575963718820862
# acc :  0.7068965517241379
# sensitivity :  0.6666666666666666
# specificity :  0.7142857142857143
# pr_auc :  0.42142647379099746
#
# [[35 14]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    165
# 0    154
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.49237812287460536
# roc_auc_score :  0.6574074074074073
# acc :  0.8947368421052632
# sensitivity :  0.4444444444444444
# specificity :  0.9791666666666666
# pr_auc :  0.44876490247984774
#
# [[47  1]
#  [ 5  4]]
#  변화된 값의 분포 :
#  1    159
# 0    154
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.3583624492045618
# roc_auc_score :  0.6583333333333334
# acc :  0.7931034482758621
# sensitivity :  0.6
# specificity :  0.8333333333333334
# pr_auc :  0.38093364963524223
#
# [[40  8]
#  [ 4  6]]
#  변화된 값의 분포 :
#  1    163
# 0    154
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.1611909455607668
# roc_auc_score :  0.7145833333333333
# acc :  0.8448275862068966
# sensitivity :  0.6
# specificity :  0.8958333333333334
# pr_auc :  0.4027908055128391
#
# [[43  5]
#  [ 4  6]]
#  변화된 값의 분포 :
#  1    162
# 0    154
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.01894882152176893
# roc_auc_score :  0.6291666666666667
# acc :  0.4482758620689655
# sensitivity :  1.0
# specificity :  0.3333333333333333
# pr_auc :  0.2192259781736486
#
# [[16 32]
#  [ 0 10]]
#  변화된 값의 분포 :
#  0    153
# 1    148
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.480754078257256
# roc_auc_score :  0.41043083900226757
# acc :  0.3448275862068966
# sensitivity :  0.7777777777777778
# specificity :  0.2653061224489796
# pr_auc :  0.12400030969029227
#
# [[13 36]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1    150
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.3714270179995874
# roc_auc_score :  0.6736111111111112
# acc :  0.7192982456140351
# sensitivity :  0.5555555555555556
# specificity :  0.75
# pr_auc :  0.32756892445884855
#
# [[36 12]
#  [ 4  5]]
#  변화된 값의 분포 :
#  1    163
# 0    154
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.34666499238165227
# roc_auc_score :  0.7229166666666667
# acc :  0.8103448275862069
# sensitivity :  0.6
# specificity :  0.8541666666666666
# pr_auc :  0.29047733898659045
#
# [[41  7]
#  [ 4  6]]
#  변화된 값의 분포 :
#  1    163
# 0    154
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.036475911796685516
# roc_auc_score :  0.5854166666666667
# acc :  0.5344827586206896
# sensitivity :  0.8
# specificity :  0.4791666666666667
# pr_auc :  0.1912034857260053
#
# [[23 25]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    159
# 0    154
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.49868480857050074
# roc_auc_score :  0.6552083333333333
# acc :  0.6379310344827587
# sensitivity :  0.7
# specificity :  0.625
# pr_auc :  0.26407615765604486
#
# [[30 18]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    162
# 0    153
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.26229331257697924
# roc_auc_score :  0.5986394557823129
# acc :  0.7068965517241379
# sensitivity :  0.5555555555555556
# specificity :  0.7346938775510204
# pr_auc :  0.26805204305707814
#
# [[36 13]
#  [ 4  5]]
#  변화된 값의 분포 :
#  0    154
# 1    152
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.38111787169317185
# roc_auc_score :  0.6203703703703703
# acc :  0.8421052631578947
# sensitivity :  0.3333333333333333
# specificity :  0.9375
# pr_auc :  0.3490210845000395
#
# [[45  3]
#  [ 6  3]]
#  변화된 값의 분포 :
#  1    162
# 0    154
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.27279415665619494
# roc_auc_score :  0.6708333333333333
# acc :  0.8103448275862069
# sensitivity :  0.5
# specificity :  0.875
# pr_auc :  0.3354067453471825
#
# [[42  6]
#  [ 5  5]]
#  변화된 값의 분포 :
#  1    167
# 0    154
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.08024347198997472
# roc_auc_score :  0.7541666666666667
# acc :  0.6379310344827587
# sensitivity :  0.9
# specificity :  0.5833333333333334
# pr_auc :  0.3059589911786453
#
# [[28 20]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    154
# 1    150
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.21987138636082154
# roc_auc_score :  0.6520833333333333
# acc :  0.6379310344827587
# sensitivity :  0.8
# specificity :  0.6041666666666666
# pr_auc :  0.25393500611250946
#
# [[29 19]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    162
# 0    153
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.12722661202346042
# roc_auc_score :  0.7006802721088435
# acc :  0.7586206896551724
# sensitivity :  0.5555555555555556
# specificity :  0.7959183673469388
# pr_auc :  0.26169602681880977
#
# [[39 10]
#  [ 4  5]]
#  변화된 값의 분포 :
#  0    154
# 1    149
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.4709741797144132
# roc_auc_score :  0.8541666666666666
# acc :  0.7017543859649122
# sensitivity :  1.0
# specificity :  0.6458333333333334
# pr_auc :  0.587974075670154
#
# [[31 17]
#  [ 0  9]]

# %%
print('adasyn : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# adasyn :
# proba_score 0.6698430413832199
# re_score 0.7094444444444445
# specifi_score 0.6692602040816327
# [0.6625,
#  0.8604166666666666,
#  0.6583333333333333,
#  0.6575963718820862,
#  0.6574074074074073,
#  0.6583333333333334,
#  0.7145833333333333,
#  0.6291666666666667,
#  0.41043083900226757,
#  0.6736111111111112,
#  0.7229166666666667,
#  0.5854166666666667,
#  0.6552083333333333,
#  0.5986394557823129,
#  0.6203703703703703,
#  0.6708333333333333,
#  0.7541666666666667,
#  0.6520833333333333,
#  0.7006802721088435,
#  0.8541666666666666]

# %% [markdown]
# # SMOTETomek

# %%
from imblearn.combine import SMOTETomek 
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    s_tomek = SMOTETomek(random_state = 42)
    x_train, y_train = s_tomek.fit_resample(x_train, y_train)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train_sk).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.15515048109536442
# roc_auc_score :  0.7375
# acc :  0.7241379310344828
# sensitivity :  0.7
# specificity :  0.7291666666666666
# pr_auc :  0.5022289007482466
#
# [[35 13]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.35891395645632435
# roc_auc_score :  0.70625
# acc :  0.6379310344827587
# sensitivity :  0.9
# specificity :  0.5833333333333334
# pr_auc :  0.27451150260023394
#
# [[28 20]
#  [ 1  9]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.446136226117855
# roc_auc_score :  0.75
# acc :  0.8103448275862069
# sensitivity :  0.7
# specificity :  0.8333333333333334
# pr_auc :  0.46173495754891103
#
# [[40  8]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    153
# 1     31
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.058079911145375106
# roc_auc_score :  0.7120181405895691
# acc :  0.7931034482758621
# sensitivity :  0.6666666666666666
# specificity :  0.8163265306122449
# pr_auc :  0.452692363548418
#
# [[40  9]
#  [ 3  6]]
#  변화된 값의 분포 :
#  0    154
# 1     31
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.18903306555914764
# roc_auc_score :  0.6157407407407408
# acc :  0.631578947368421
# sensitivity :  0.6666666666666666
# specificity :  0.625
# pr_auc :  0.2614514575516188
#
# [[30 18]
#  [ 3  6]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.34112884947126176
# roc_auc_score :  0.7729166666666667
# acc :  0.7758620689655172
# sensitivity :  0.7
# specificity :  0.7916666666666666
# pr_auc :  0.4946863246726948
#
# [[38 10]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.20024196732074231
# roc_auc_score :  0.55625
# acc :  0.7241379310344828
# sensitivity :  0.4
# specificity :  0.7916666666666666
# pr_auc :  0.2926076933843238
#
# [[38 10]
#  [ 6  4]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.07020590936808627
# roc_auc_score :  0.5979166666666667
# acc :  0.3793103448275862
# sensitivity :  1.0
# specificity :  0.25
# pr_auc :  0.37791784238613
#
# [[12 36]
#  [ 0 10]]
#  변화된 값의 분포 :
#  0    153
# 1     31
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.4923714325338307
# roc_auc_score :  0.5204081632653061
# acc :  0.7413793103448276
# sensitivity :  0.3333333333333333
# specificity :  0.8163265306122449
# pr_auc :  0.16031049165107136
#
# [[40  9]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1     31
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.3049846319768359
# roc_auc_score :  0.7361111111111112
# acc :  0.7017543859649122
# sensitivity :  0.7777777777777778
# specificity :  0.6875
# pr_auc :  0.3315216709579455
#
# [[33 15]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.07248193169769376
# roc_auc_score :  0.58125
# acc :  0.5172413793103449
# sensitivity :  0.8
# specificity :  0.4583333333333333
# pr_auc :  0.2880250418534125
#
# [[22 26]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.08105149727299657
# roc_auc_score :  0.675
# acc :  0.5862068965517241
# sensitivity :  0.8
# specificity :  0.5416666666666666
# pr_auc :  0.3520503731540242
#
# [[26 22]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.12547858354357874
# roc_auc_score :  0.7145833333333335
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.44607124904264983
#
# [[36 12]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    153
# 1     31
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.4874941739954046
# roc_auc_score :  0.5056689342403629
# acc :  0.7758620689655172
# sensitivity :  0.3333333333333333
# specificity :  0.8571428571428571
# pr_auc :  0.18492237558063887
#
# [[42  7]
#  [ 6  3]]
#  변화된 값의 분포 :
#  0    154
# 1     31
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.08046643189707602
# roc_auc_score :  0.7199074074074074
# acc :  0.6666666666666666
# sensitivity :  0.7777777777777778
# specificity :  0.6458333333333334
# pr_auc :  0.3275786676932702
#
# [[31 17]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.08875559850080118
# roc_auc_score :  0.6145833333333334
# acc :  0.6724137931034483
# sensitivity :  0.8
# specificity :  0.6458333333333334
# pr_auc :  0.20915314645593586
#
# [[31 17]
#  [ 2  8]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.29327069927912675
# roc_auc_score :  0.6104166666666666
# acc :  0.8103448275862069
# sensitivity :  0.4
# specificity :  0.8958333333333334
# pr_auc :  0.35333589897128515
#
# [[43  5]
#  [ 6  4]]
#  변화된 값의 분포 :
#  0    154
# 1     30
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.09444894870047515
# roc_auc_score :  0.6979166666666666
# acc :  0.7586206896551724
# sensitivity :  0.7
# specificity :  0.7708333333333334
# pr_auc :  0.4527287947423796
#
# [[37 11]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    153
# 1     31
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.39483812907882254
# roc_auc_score :  0.6780045351473922
# acc :  0.7241379310344828
# sensitivity :  0.6666666666666666
# specificity :  0.7346938775510204
# pr_auc :  0.4057039289172932
#
# [[36 13]
#  [ 3  6]]
#  변화된 값의 분포 :
#  0    154
# 1     31
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.4685951028899102
# roc_auc_score :  0.6111111111111112
# acc :  0.631578947368421
# sensitivity :  0.7777777777777778
# specificity :  0.6041666666666666
# pr_auc :  0.18898467090207555
#
# [[29 19]
#  [ 2  7]]

# %%
print('SMOTETomek 5 4 : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# SMOTETomek 5 4 :
# proba_score 0.6556776738473167
# re_score 0.68
# specifi_score 0.6914328231292518
# [0.7375,
#  0.70625,
#  0.75,
#  0.7120181405895691,
#  0.6157407407407408,
#  0.7729166666666667,
#  0.55625,
#  0.5979166666666667,
#  0.5204081632653061,
#  0.7361111111111112,
#  0.58125,
#  0.675,
#  0.7145833333333335,
#  0.5056689342403629,
#  0.7199074074074074,
#  0.6145833333333334,
#  0.6104166666666666,
#  0.6979166666666666,
#  0.6780045351473922,
#  0.6111111111111112]

# %% [markdown]
# # SMOTEENN

# %%
from imblearn.combine import SMOTEENN 
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    s_enn = SMOTEENN(random_state=42)
    x_train, y_train = s_enn.fit_resample(x_train, y_train)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  1    190
# 0     37
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.15515048109536442
# roc_auc_score :  0.7375
# acc :  0.7241379310344828
# sensitivity :  0.7
# specificity :  0.7291666666666666
# pr_auc :  0.5022289007482466
#
# [[35 13]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    185
# 0     36
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.35891395645632435
# roc_auc_score :  0.70625
# acc :  0.6379310344827587
# sensitivity :  0.9
# specificity :  0.5833333333333334
# pr_auc :  0.27451150260023394
#
# [[28 20]
#  [ 1  9]]
#  변화된 값의 분포 :
#  1    186
# 0     53
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.446136226117855
# roc_auc_score :  0.75
# acc :  0.8103448275862069
# sensitivity :  0.7
# specificity :  0.8333333333333334
# pr_auc :  0.46173495754891103
#
# [[40  8]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    184
# 0     42
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.058079911145375106
# roc_auc_score :  0.7120181405895691
# acc :  0.7931034482758621
# sensitivity :  0.6666666666666666
# specificity :  0.8163265306122449
# pr_auc :  0.452692363548418
#
# [[40  9]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    187
# 0     39
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.18903306555914764
# roc_auc_score :  0.6157407407407408
# acc :  0.631578947368421
# sensitivity :  0.6666666666666666
# specificity :  0.625
# pr_auc :  0.2614514575516188
#
# [[30 18]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    189
# 0     43
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.34112884947126176
# roc_auc_score :  0.7729166666666667
# acc :  0.7758620689655172
# sensitivity :  0.7
# specificity :  0.7916666666666666
# pr_auc :  0.4946863246726948
#
# [[38 10]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    188
# 0     57
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.20024196732074231
# roc_auc_score :  0.55625
# acc :  0.7241379310344828
# sensitivity :  0.4
# specificity :  0.7916666666666666
# pr_auc :  0.2926076933843238
#
# [[38 10]
#  [ 6  4]]
#  변화된 값의 분포 :
#  1    190
# 0     31
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.07020590936808627
# roc_auc_score :  0.5979166666666667
# acc :  0.3793103448275862
# sensitivity :  1.0
# specificity :  0.25
# pr_auc :  0.37791784238613
#
# [[12 36]
#  [ 0 10]]
#  변화된 값의 분포 :
#  1    188
# 0     52
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.4923714325338307
# roc_auc_score :  0.5204081632653061
# acc :  0.7413793103448276
# sensitivity :  0.3333333333333333
# specificity :  0.8163265306122449
# pr_auc :  0.16031049165107136
#
# [[40  9]
#  [ 6  3]]
#  변화된 값의 분포 :
#  1    187
# 0     29
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.3049846319768359
# roc_auc_score :  0.7361111111111112
# acc :  0.7017543859649122
# sensitivity :  0.7777777777777778
# specificity :  0.6875
# pr_auc :  0.3315216709579455
#
# [[33 15]
#  [ 2  7]]
#  변화된 값의 분포 :
#  1    188
# 0     43
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.07248193169769376
# roc_auc_score :  0.58125
# acc :  0.5172413793103449
# sensitivity :  0.8
# specificity :  0.4583333333333333
# pr_auc :  0.2880250418534125
#
# [[22 26]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    185
# 0     49
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.08105149727299657
# roc_auc_score :  0.675
# acc :  0.5862068965517241
# sensitivity :  0.8
# specificity :  0.5416666666666666
# pr_auc :  0.3520503731540242
#
# [[26 22]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    190
# 0     30
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.12547858354357874
# roc_auc_score :  0.7145833333333335
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.44607124904264983
#
# [[36 12]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    187
# 0     56
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.4874941739954046
# roc_auc_score :  0.5056689342403629
# acc :  0.7758620689655172
# sensitivity :  0.3333333333333333
# specificity :  0.8571428571428571
# pr_auc :  0.18492237558063887
#
# [[42  7]
#  [ 6  3]]
#  변화된 값의 분포 :
#  1    192
# 0     36
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.08046643189707602
# roc_auc_score :  0.7199074074074074
# acc :  0.6666666666666666
# sensitivity :  0.7777777777777778
# specificity :  0.6458333333333334
# pr_auc :  0.3275786676932702
#
# [[31 17]
#  [ 2  7]]
#  변화된 값의 분포 :
#  1    186
# 0     52
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.08875559850080118
# roc_auc_score :  0.6145833333333334
# acc :  0.6724137931034483
# sensitivity :  0.8
# specificity :  0.6458333333333334
# pr_auc :  0.20915314645593586
#
# [[31 17]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    191
# 0     35
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.29327069927912675
# roc_auc_score :  0.6104166666666666
# acc :  0.8103448275862069
# sensitivity :  0.4
# specificity :  0.8958333333333334
# pr_auc :  0.35333589897128515
#
# [[43  5]
#  [ 6  4]]
#  변화된 값의 분포 :
#  1    189
# 0     37
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.09444894870047515
# roc_auc_score :  0.6979166666666666
# acc :  0.7586206896551724
# sensitivity :  0.7
# specificity :  0.7708333333333334
# pr_auc :  0.4527287947423796
#
# [[37 11]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    188
# 0     50
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.39483812907882254
# roc_auc_score :  0.6780045351473922
# acc :  0.7241379310344828
# sensitivity :  0.6666666666666666
# specificity :  0.7346938775510204
# pr_auc :  0.4057039289172932
#
# [[36 13]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    188
# 0     33
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.4685951028899102
# roc_auc_score :  0.6111111111111112
# acc :  0.631578947368421
# sensitivity :  0.7777777777777778
# specificity :  0.6041666666666666
# pr_auc :  0.18898467090207555
#
# [[29 19]
#  [ 2  7]]

# %%
print('SMOTEENN 5 4 : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# SMOTEENN 5 4 :
# proba_score 0.6556776738473167
# re_score 0.68
# specifi_score 0.6914328231292518
# [0.7375,
#  0.70625,
#  0.75,
#  0.7120181405895691,
#  0.6157407407407408,
#  0.7729166666666667,
#  0.55625,
#  0.5979166666666667,
#  0.5204081632653061,
#  0.7361111111111112,
#  0.58125,
#  0.675,
#  0.7145833333333335,
#  0.5056689342403629,
#  0.7199074074074074,
#  0.6145833333333334,
#  0.6104166666666666,
#  0.6979166666666666,
#  0.6780045351473922,
#  0.6111111111111112]

# %% [markdown]
# # RandomOverSampler

# %%
from imblearn.over_sampling import RandomOverSampler
seed = 7
skfold = RepeatedStratifiedKFold(n_splits=5,random_state=seed,n_repeats=4)

proba_score = []
predict_score = []
acc_score = []
re_score = []
prauc_score = []
specifi_score = []
cm1_score = []

curve_fprs = []
curve_tprs = []
curve_thresholds = []

curve_pre = []
curve_rec = []
curve_thr = []

tprs_ls = []
mean_fpr = np.linspace(0,1,100)

x_df = merge_df.drop(['Key','cutoff'],axis=1)
y_df = merge_df['cutoff']

sc = StandardScaler()
x_df = pd.DataFrame(sc.fit_transform(x_df), columns=x_df.columns)

for j, (train_idx, val_idx) in enumerate(skfold.split(x_df,y_df)):

    x_train, y_train = x_df.iloc[train_idx], y_df.iloc[train_idx]
    x_test, y_test = x_df.iloc[val_idx], y_df.iloc[val_idx]

    x_train_sk, x_val_sk, y_train_sk, y_val_sk = train_test_split(x_train,y_train,stratify=y_train, random_state=seed, test_size=0.2)

    oversample = RandomOverSampler(sampling_strategy='minority')
    x_train, y_train = oversample.fit_resample(x_train, y_train)
    print(' 변화된 값의 분포 :\n',pd.Series(y_train).value_counts() )
    
    
    model = catboost.CatBoostClassifier(
                                    use_best_model=True,
                                    eval_metric='AUC',
                                    verbose=False,
                                    random_state=seed
                                    )
    D_train = catboost.Pool(x_train_sk, y_train_sk)
    D_test = catboost.Pool(x_val_sk, y_val_sk)

    model.fit(D_train, eval_set=D_test, verbose=False)

    pred = model.predict_proba(x_test)[:,1]
    fprs, tprs, thresholds = roc_curve(y_test, pred)

    tprs_ls.append(np.interp(mean_fpr, fprs, tprs))

    curve_tprs.append(tprs)
    curve_fprs.append(fprs)
    curve_thresholds.append(thresholds)

    J = tprs - fprs
    ix = np.argmax(J)
    best_thresh = thresholds[ix]

    precision, recall, th = precision_recall_curve(y_test, pred)
    prauc = auc(recall, precision)

    curve_pre.append(precision)
    curve_rec.append(recall)
    curve_thr.append(th)
        
    cm1 = confusion_matrix(y_test, np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0))

    Specificity = cm1[0,0]/(cm1[0,0]+cm1[0,1])
    Sensitivity = cm1[1,1]/(cm1[1,0]+cm1[1,1])
    print(j,'번째')
    print('Youden index threshold : ',best_thresh)

    print('roc_auc_score : ',roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    print('acc : ',accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    print('sensitivity : ',Sensitivity)
    print('specificity : ',Specificity)
    print('pr_auc : ',prauc,'\n')
    print(cm1)

    proba_score.append(roc_auc_score(y_test,model.predict_proba(x_test)[:,1]))
    acc_score.append(accuracy_score(y_test,np.where(model.predict_proba(x_test)[:,1] >= best_thresh , 1, 0)))
    re_score.append(Sensitivity)
    specifi_score.append(Specificity)
    prauc_score.append(prauc)
    cm1_score.append(cm1)
# Out:
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 0 번째
# Youden index threshold :  0.15515048109536442
# roc_auc_score :  0.7375
# acc :  0.7241379310344828
# sensitivity :  0.7
# specificity :  0.7291666666666666
# pr_auc :  0.5022289007482466
#
# [[35 13]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    193
# 1    193
# Name: cutoff, dtype: int64
# 1 번째
# Youden index threshold :  0.35891395645632435
# roc_auc_score :  0.70625
# acc :  0.6379310344827587
# sensitivity :  0.9
# specificity :  0.5833333333333334
# pr_auc :  0.27451150260023394
#
# [[28 20]
#  [ 1  9]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 2 번째
# Youden index threshold :  0.446136226117855
# roc_auc_score :  0.75
# acc :  0.8103448275862069
# sensitivity :  0.7
# specificity :  0.8333333333333334
# pr_auc :  0.46173495754891103
#
# [[40  8]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    192
# 0    192
# Name: cutoff, dtype: int64
# 3 번째
# Youden index threshold :  0.058079911145375106
# roc_auc_score :  0.7120181405895691
# acc :  0.7931034482758621
# sensitivity :  0.6666666666666666
# specificity :  0.8163265306122449
# pr_auc :  0.452692363548418
#
# [[40  9]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 4 번째
# Youden index threshold :  0.18903306555914764
# roc_auc_score :  0.6157407407407408
# acc :  0.631578947368421
# sensitivity :  0.6666666666666666
# specificity :  0.625
# pr_auc :  0.2614514575516188
#
# [[30 18]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 5 번째
# Youden index threshold :  0.34112884947126176
# roc_auc_score :  0.7729166666666667
# acc :  0.7758620689655172
# sensitivity :  0.7
# specificity :  0.7916666666666666
# pr_auc :  0.4946863246726948
#
# [[38 10]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 6 번째
# Youden index threshold :  0.20024196732074231
# roc_auc_score :  0.55625
# acc :  0.7241379310344828
# sensitivity :  0.4
# specificity :  0.7916666666666666
# pr_auc :  0.2926076933843238
#
# [[38 10]
#  [ 6  4]]
#  변화된 값의 분포 :
#  0    193
# 1    193
# Name: cutoff, dtype: int64
# 7 번째
# Youden index threshold :  0.07020590936808627
# roc_auc_score :  0.5979166666666667
# acc :  0.3793103448275862
# sensitivity :  1.0
# specificity :  0.25
# pr_auc :  0.37791784238613
#
# [[12 36]
#  [ 0 10]]
#  변화된 값의 분포 :
#  1    192
# 0    192
# Name: cutoff, dtype: int64
# 8 번째
# Youden index threshold :  0.4923714325338307
# roc_auc_score :  0.5204081632653061
# acc :  0.7413793103448276
# sensitivity :  0.3333333333333333
# specificity :  0.8163265306122449
# pr_auc :  0.16031049165107136
#
# [[40  9]
#  [ 6  3]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 9 번째
# Youden index threshold :  0.3049846319768359
# roc_auc_score :  0.7361111111111112
# acc :  0.7017543859649122
# sensitivity :  0.7777777777777778
# specificity :  0.6875
# pr_auc :  0.3315216709579455
#
# [[33 15]
#  [ 2  7]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 10 번째
# Youden index threshold :  0.07248193169769376
# roc_auc_score :  0.58125
# acc :  0.5172413793103449
# sensitivity :  0.8
# specificity :  0.4583333333333333
# pr_auc :  0.2880250418534125
#
# [[22 26]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 11 번째
# Youden index threshold :  0.08105149727299657
# roc_auc_score :  0.675
# acc :  0.5862068965517241
# sensitivity :  0.8
# specificity :  0.5416666666666666
# pr_auc :  0.3520503731540242
#
# [[26 22]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 12 번째
# Youden index threshold :  0.12547858354357874
# roc_auc_score :  0.7145833333333335
# acc :  0.7413793103448276
# sensitivity :  0.7
# specificity :  0.75
# pr_auc :  0.44607124904264983
#
# [[36 12]
#  [ 3  7]]
#  변화된 값의 분포 :
#  0    192
# 1    192
# Name: cutoff, dtype: int64
# 13 번째
# Youden index threshold :  0.4874941739954046
# roc_auc_score :  0.5056689342403629
# acc :  0.7758620689655172
# sensitivity :  0.3333333333333333
# specificity :  0.8571428571428571
# pr_auc :  0.18492237558063887
#
# [[42  7]
#  [ 6  3]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 14 번째
# Youden index threshold :  0.08046643189707602
# roc_auc_score :  0.7199074074074074
# acc :  0.6666666666666666
# sensitivity :  0.7777777777777778
# specificity :  0.6458333333333334
# pr_auc :  0.3275786676932702
#
# [[31 17]
#  [ 2  7]]
#  변화된 값의 분포 :
#  0    193
# 1    193
# Name: cutoff, dtype: int64
# 15 번째
# Youden index threshold :  0.08875559850080118
# roc_auc_score :  0.6145833333333334
# acc :  0.6724137931034483
# sensitivity :  0.8
# specificity :  0.6458333333333334
# pr_auc :  0.20915314645593586
#
# [[31 17]
#  [ 2  8]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 16 번째
# Youden index threshold :  0.29327069927912675
# roc_auc_score :  0.6104166666666666
# acc :  0.8103448275862069
# sensitivity :  0.4
# specificity :  0.8958333333333334
# pr_auc :  0.35333589897128515
#
# [[43  5]
#  [ 6  4]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 17 번째
# Youden index threshold :  0.09444894870047515
# roc_auc_score :  0.6979166666666666
# acc :  0.7586206896551724
# sensitivity :  0.7
# specificity :  0.7708333333333334
# pr_auc :  0.4527287947423796
#
# [[37 11]
#  [ 3  7]]
#  변화된 값의 분포 :
#  1    192
# 0    192
# Name: cutoff, dtype: int64
# 18 번째
# Youden index threshold :  0.39483812907882254
# roc_auc_score :  0.6780045351473922
# acc :  0.7241379310344828
# sensitivity :  0.6666666666666666
# specificity :  0.7346938775510204
# pr_auc :  0.4057039289172932
#
# [[36 13]
#  [ 3  6]]
#  변화된 값의 분포 :
#  1    193
# 0    193
# Name: cutoff, dtype: int64
# 19 번째
# Youden index threshold :  0.4685951028899102
# roc_auc_score :  0.6111111111111112
# acc :  0.631578947368421
# sensitivity :  0.7777777777777778
# specificity :  0.6041666666666666
# pr_auc :  0.18898467090207555
#
# [[29 19]
#  [ 2  7]]

# %%
print('RandomOverSampler 5 4 : ')
print('proba_score',np.mean(proba_score))
print('re_score',np.mean(re_score))
print('specifi_score',np.mean(specifi_score))
proba_score
# Out:
# RandomOverSampler 5 4 :
# proba_score 0.6556776738473167
# re_score 0.68
# specifi_score 0.6914328231292518
# [0.7375,
#  0.70625,
#  0.75,
#  0.7120181405895691,
#  0.6157407407407408,
#  0.7729166666666667,
#  0.55625,
#  0.5979166666666667,
#  0.5204081632653061,
#  0.7361111111111112,
#  0.58125,
#  0.675,
#  0.7145833333333335,
#  0.5056689342403629,
#  0.7199074074074074,
#  0.6145833333333334,
#  0.6104166666666666,
#  0.6979166666666666,
#  0.6780045351473922,
#  0.6111111111111112]
